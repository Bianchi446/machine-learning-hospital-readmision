# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
diabetic_data = pd.read_csv("../data/diabetic_data.csv")
diabetic_data
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
print("length of data :", len(diabetic_data))
# Out:
# length of data : 99343

# %% [markdown]
# ###  Given this set of data, we try to define:
#
# Problem 1 : Determine what is "Success" for the ML algorithm trainned with this data.
#
# 90% Accuracy in predicting wheter a patient have been readmitted or not.

# %%
diabetic_data['readmitted'].value_counts()
# Out:
# NO     52527
# >30    35502
# <30    11314
# Name: readmitted, dtype: int64

# %%
diabetic_data['readmitted'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
diabetic_data.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  9.934300e+04  9.934300e+04       99343.000000
# mean   1.649689e+08  5.426117e+07           2.030259
# std    1.026535e+08  3.873426e+07           1.446373
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.469034e+07  2.338675e+07           1.000000
# 50%    1.522321e+08  4.541774e+07           1.000000
# 75%    2.301018e+08  8.756007e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count              99343.000000         99343.000000      99343.000000
# mean                   3.517882             5.731083          4.379332
# std                    5.184359             4.065029          2.968409
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %% [markdown]
# ### Performing data imputation :
#
# Since for now we can really know if weight would be an important feature of the final predicted output, imputation of this data is neccesary.
#
# The following questions must be addressed when performing value imputation :
#
# Do you have knowledge or suspicion that missing data occurs in a biased
# way?
#
# Do you have a lot of data?
#
# What is the role of the missing data ?
#
# Concepts
# • Identifying values to impute
#
# • Central tendency within a dataset
#
# • Mean, median, geometric mean, and multi-modal data
#
# • Population-based central tendency
#
# • Neighboring data expressing a tendency
